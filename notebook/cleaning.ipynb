# %%
from csv import reader
from math import sqrt
import pandas as pd
import pickle

# %% [markdown]
# # reading csv files

# %%
movie_columns = ['movieId', 'title', 'genres']
tag_columns = ['movieId', 'userId', 'tag']
ratings_columns = ['movieId', 'userId', 'rating', 'timestamp']
movies_df = pd.read_csv("../data/movies.csv")[movie_columns]
tags_df = pd.read_csv("../data/tags.csv")[tag_columns]
ratings_df = pd.read_csv("../data/ratings.csv")[ratings_columns]

# %% [markdown]
# # column categorization

# %%
category = {}
category["title"] = dict(enumerate(movies_df['title'].astype('category').cat.categories))
category["genres"] = dict(enumerate(movies_df['genres'].astype('category').cat.categories))
category["tag"] = dict(enumerate(tags_df['tag'].astype('category').cat.categories))

# %%
tags_df['tag']=tags_df['tag'].astype('category').cat.codes
movies_df['title']=movies_df['title'].astype('category').cat.codes
movies_df['genres']=movies_df['genres'].astype('category').cat.codes

# %% [markdown]
# # join

# %%
tags_grouped_df = tags_df.groupby(['movieId', 'userId'], as_index=False)['tag'].agg(list)
df_tag_rating =  ratings_df.merge(tags_grouped_df, how='left', on=['movieId', 'userId'])
df_movies_tag_rating =  df_tag_rating.merge(movies_df, how='inner', on=['movieId'])

# %%
df_movies_tag_rating.rename(columns = {'timestamp':'timestamp_rating'}, inplace = True)
df_movies = df_movies_tag_rating[['movieId', 'userId', 'rating', 'timestamp_rating', 'tag', 'title', 'genres']]

# %% [markdown]
# # validate results

# %%
movies_df = pd.read_csv("../data/movies.csv")[movie_columns]
movies_df.loc[(movies_df['movieId']==1)]
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
tags_df = pd.read_csv("../data/tags.csv")[tag_columns]
tags_df.loc[(tags_df['userId']==791)].iloc[0]['tag']
# Out:
# 'Owned'

# %%
df_movies_tag_rating.loc[(df_movies_tag_rating['movieId']==1)&(df_movies_tag_rating['userId']==791)]
# Out:
#         movieId  userId  rating  timestamp_rating      tag  title  genres
# 601448        1     791     4.5        1515175489  [19014]  57003     594

# %%
print(f"""TAG: {category['tag'][19014]}
TITLE: {category['title'][57003]}
GENRE: {category['genres'][594]}""")
# Out:
# TAG: Owned
# TITLE: Toy Story (1995)
# GENRE: Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# # Save

# %%
df_movies_tag_rating.to_parquet('../results/entity.parquet')

# %%
with open('../results/category.pickle', 'wb') as handle:
    pickle.dump(category, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
pd.read_parquet('../results/entity.parquet')
# Out:
#           movieId  userId  rating  timestamp_rating   tag  title  genres
# 0             296       1     5.0        1147880044  None  39812    1160
# 1             296       3     5.0        1439474476  None  39812    1160
# 2             296       4     4.0        1573938898  None  39812    1160
# 3             296       5     4.0         830786155  None  39812    1160
# 4             296       7     4.0         835444730  None  39812    1160
# ...           ...     ...     ...               ...   ...    ...     ...
# 25000090   200192  162358     2.0        1553453039  None  13650       0
# 25000091   200194  162358     2.0        1553453843  None  56951     216
# 25000092   139970  162386     3.5        1549215965  None  23941    1136
# 25000093   200726  162386     4.0        1554651417  None  51178    1087
# 25000094   200728  162386     4.0        1554651472  None  24483       0
#
# [25000095 rows x 7 columns]

# %%
with open('../results/category.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
b
# Out:
# {'title': {0: '"BLOW THE NIGHT!" Let\'s Spend the Night Together (1983)',
#   1: '"Great Performances" Cats (1998)',
#   2: '#1 Cheerleader Camp (2010)',
#   3: '#Captured (2017)',
#   4: '#Female Pleasure (2018)',
#   5: '#FollowMe (2019)',
#   6: '#Horror (2015)',
#   7: '#Lucky Number (2015)',
#   8: '#SCREAMERS (2016)',
#   9: '#SquadGoals (2018)',
#   10: '#Stuck (2014)',
#   11: '#realityhigh (2017)',
#   12: '$ (Dollars) (1971)',
#   13: '$1,000 on the Black (1966)',
#   14: '$100,000 for Ringo (1965)',
#   15: '$5 a Day (2008)',
#   16: '$50K and a Call Girl: A Love Story (2014)',
#   17: '$9.99 (2008)',
#   18: '$ellebrity (Sellebrity) (2012)',
#   19: "$uperthief: Inside America's Biggest Bank Score (2012)",
#   20: "'49-'17 (1917)",
#   21: "'63 Boycott (2016)",
#   22: "'68 (1988)",
#   23: "'71 (2014)",
#   24: "'Gator Bait (1974)",
#   25: "'Hellboy': The Seeds of Creation (2004)",
#   26: "'Human' Factor, The (Human Factor, The) (1975)",
#   27: "'Master Harold' ... And the Boys (2010)",
#   28: "'Master Harold'... and the Boys (1985)",
#   29: "'Neath Brooklyn Bridge (1942)",
#   30: "'Neath the Arizona Skies (1934)",
#   31: "'Pimpernel' Smith (1941)",
#   32: "'R Xmas (2001)",
#   33: "'Round Midnight (1986)",
#   34: "'Salem's Lot (2004)",
#   35: "'Til Madness Do Us Part (2013)",
#   36: "'Til There Was You (1997)",
#   37: "'Tis the Season for Love (2015)",
#   38: "'Twas the Night (2001)",
#   39: "'Twas the Night Before Christmas (1974)",
#   40: "'burbs, The (1989)",
#   41: "'night Mother (1986)",
#   42: '(500) Days of Summer (2009)',
#   43: '(A)sexual (2011)',
#   44: '(Dis)Honesty: The Truth About Lies (2015)',
#   45: '(Girl)Friend (2018)',
#   46: '(T)ERROR (2015)',
#   47: '(The New) War of the Buttons (2011)',
#   48: '(Untitled) (2009)',
#   49: '*batteries not included (1987)',
#   50: '+1 (2013)',
#   51: '...All the Marbles (1981)',
#   52: '...And God Spoke (1993)',
#   53: '...And Justice for All (1979)',
#   54: '...And the Earth Did Not Swallow Him (1995)',
#   55: '...E fuori nevica! (2014)',
#   56: '...First Do No Harm (1997)',
#   57: '...ing (2003)',
#   58: '...tick... tick... tick... (1970)',
#   59: '.45 (2006)',
#   60: '.hack Liminality In the Case of Kyoko Tohno',
#   61: '.hack Liminality In the Case of Yuki Aihara',
#   62: '.hack Liminality: In the Case of Mai Minase',
#   63: '.hack//Beyond the World (2012)',
#   64: '0.5mm (2014)',
#   65: '00 Schneider - Im Wendekreis der Eidechse (2013)',
#   66: '00 Schneider - Jagd auf Nihil Baxter (1994)',
#   67: '008: Operation Exterminate (1966)',
#   68: '009 Re: Cyborg (2012)',
#   69: '009-1: The End of the Beginning (2013)',
#   70: '07/27/1978 (2017)',
#   71: '08/15 (1954)',
#   72: '09:06 (2009)',
#   73: '1 (2013)',
#   74: '1 (2014)',
#   75: '1 Buck (2017)',
#   76: '1 Chance 2 Dance (2014)',
#   77: '1 Journée (2007)',
#   78: '1 Litre of Tears (2005)',
#   79: '1 Mile to You (2017)',
#   80: '1 Night (2017)',
#   81: '1 Out of 7 (2012)',
#   82: '1 P.M. (1972)',
#   83: '1% (2019)',
#   84: '1, 2, 3, Sun (Un, deuz, trois, soleil) (1993)',
#   85: '1, 2, 3, voleurs (2011)',
#   86: '1-900 (06) (1994)',
#   87: '1-Ichi (2003)',
#   88: '1. Mai (2008)',
#   89: '1/1 (2018)',
#   90: '10 (1979)',
#   91: '10 000 timmar (2014)',
#   92: '10 Attitudes (2001)',
#   93: "10 Billion: What's On Your Plate (2015)",
#   94: '10 Cent Pistol (2015)',
#   95: '10 Cloverfield Lane (2016)',
#   96: '10 Days in a Madhouse (2015)',
#   97: '10 Items or Less (2006)',
#   98: '10 Minutes (2014)',
#   99: '10 Minutes Gone (2019)',
#   100: '10 Mountains 10 Years (2010)',
#   101: '10 Questions for the Dalai Lama (2006)',
#   102: '10 Rillington Place (1971)',
#   103: '10 Rules for Sleeping Around (2013)',
#   104: '10 Things I Hate About You (1999)',
#   105: '10 Years (2011)',
#   106: '10 jours en or (2012)',
#   107: '10 minutes (10 minuta) (2002)',
#   108: '10 to Midnight (1983)',
#   109: '10%: What Makes a Hero? (2013)',
#   110: '10+10 (2011)',
#   111: '10,000 BC (2008)',
#   112: '10,000 Black Men Named George (2002)',
#   113: '10,000 Days (2014)',
#   114: '10,000 Dollars for a Massacre (1967)',
#   115: '10.0 Earthquake (2014)',
#   116: '100 Bloody Acres (2012)',
#   117: '100 Days (1991)',
#   118: '100 Days Before the Command (1991)',
#   119: '100 Days Of Love (2015)',
#   120: '100 Days With Mr. Arrogant (2004)',
#   121: '100 Degrees Below Zero (2013)',
#   122: '100 Dinge (2018)',
#   123: '100 Feet (2008)',
#   124: '100 Ghost Street: The Return of Richard Speck (2012)',
#   125: '100 Girls (2000)',
#   126: '100 Men and a Girl (One Hundred Men and a Girl) (1937)',
#   127: '100 Million BC (2008)',
#   128: '100 Poems for Stella (2017)',
#   129: '100 Rifles (1969)',
#   130: '100 Streets (2016)',
#   131: '100 Tears (2007)',
#   132: '100 Women (2002)',
#   133: '100 Yards (2019)',
#   134: '100 Years at the Movies (1994)',
#   135: '100 Years of Evil (2010)',
#   136: '100 Yen Love (2014)',
#   137: '100 Yen: The Japanese Arcade Experience (2012)',
#   138: '100 grams for Bravery (1976)',
#   139: '100 metros (2016)',
#   140: '100% Love (2011)',
#   141: '1000 Eyes of Dr. Mabuse, The (Die 1000 Augen des Dr. Mabuse) (1960)',
#   142: '1000 Journals (2007)',
#   143: '1000 Rupee Note (2016)',
#   144: '1000 To 1 (2014)',
#   145: '1001 Grams (2014)',
#   146: '1001 Nights (1990)',
#   147: '101 Dalmatians (1996)',
#   148: '101 Dalmatians (One Hundred and One Dalmatians) (1961)',
#   149: "101 Dalmatians II: Patch's London Adventure (2003)",
#   150: '101 Rent Boys (2000)',
#   151: '101 Reykjavik (101 Reykjavík) (2000)',
#   152: '1013 Briar Lane',
#   153: '101次求婚',
#   154: '102 Dalmatians (2000)',
#   155: '102 Minutes That Changed America (2008)',
#   156: '102 Not Out (2018)',
#   157: '1066:  A Year to Conquer England (2017)',
#   158: '10th & Wolf (2006)',
#   159: "10th Judicial Court: Judicial Hearings, The (10e chambre - Instants d'audience) (2004)",
#   160: '10th Victim, The (La decima vittima) (1965)',
#   161: '10x10 (2018)',
#   162: '10½ (2010)',
#   163: '11 Blocks (2015)',
#   164: '11 Days 11 Nights Part 3 (1989)',
#   165: '11 Days 11 Nights: Part 1 - Fantasy Becomes Reality (1987)',
#   166: '11 Days, 11 Nights 2 (1990)',
#   167: '11 Flowers (Wo 11) (2011)',
#   168: '11 Harrowhouse (1974)',
#   169: '11 Minutes (2015)',
#   170: '11 Minutes Ago (2007)',
#   171: '11 September Vragen (2016)',
#   172: '11 x 14 (1977)',
#   173: '11\'09"01 - September 11 (2002)',
#   174: '11-11-11 (11-11-11: The Prophecy) (2011)',
#   175: '11.22.63 (2016)',
#   176: '11.6 (2013)',
#   177: '11/11/11 (2011)',
#   178: '11/8/16 (2017)',
#   179: '11:00 AM (2013)',
#   180: '11:14 (2003)',
#   181: '11:55 (2016)',
#   182: '11:59 (2005)',
#   183: '11th Hour, The (2007)',
#   184: '12 (2007)',
#   185: '12 Angry Men (1957)',
#   186: '12 Angry Men (1997)',
#   187: '12 Chairs (1971)',
#   188: '12 Chairs (1976)',
#   189: '12 Citizens (2014)',
#   190: '12 Dates of Christmas (2011)',
#   191: '12 Days (2017)',
#   192: '12 Days of Christmas Eve (2004)',
#   193: '12 Dicembre (1972)',
#   194: '12 Dogs of Christmas, The (2005)',
#   195: '12 Dogs of Christmas: Great Puppy Rescue (2012)',
#   196: '12 Feet Deep (2016)',
#   197: '12 Gifts of Christmas (2015)',
#   198: '12 Jahre (2010)',
#   199: '12 Men of Christmas (2009)',
#   200: "12 O'Clock Boys (2013)",
#   201: '12 Paces without a Head (2009)',
#   202: '12 Rounds (2009)',
#   203: '12 Rounds 3: Lockdown (2015)',
#   204: '12 Storeys (Shier lou) (1997)',
#   205: '12 Strong (2018)',
#   206: '12 Wishes of Christmas (2011)',
#   207: '12 Years a Slave (2013)',
#   208: '12 registi per 12 città (1989)',
#   209: '12 to the Moon (1960)',
#   210: '120 (2008)',
#   211: '120 Beats Per Minute (2017)',
#   212: '1210 (2012)',
#   213: '125 Years Memory (2015)',
#   214: '127 Hours (2010)',
#   215: '12:01 (1993)',
#   216: '12:08 East of Bucharest (A fost sau n-a fost?) (2006)',
#   217: '12th & Delaware (2010)',
#   218: '13 (2010)',
#   219: '13 Assassins (Jûsan-nin no shikaku) (2010)',
#   220: '13 Beloved (13 game sayawng) (2006)',
#   221: '13 Cameras (2015)',
#   222: '13 Curses (2002)',
#   223: '13 Demons (2016)',
#   224: '13 Eerie (2013)',
#   225: '13 Fighting Men (1960)',
#   226: '13 Frightened Girls! (Candy Web, The) (1963)',
#   227: '13 Ghosts (1960)',
#   228: '13 Going on 30 (2004)',
#   229: '13 Graves (2019)',
#   230: '13 Hours (2016)',
#   231: '13 Hours in a Warehouse (2008)',
#   232: '13 Lakes (2004)',
#   233: '13 Minutes (2015)',
#   234: '13 Moons (2002)',
#   235: '13 Rue Madeleine (1947)',
#   236: '13 Tzameti (2005)',
#   237: '13 West Street (1962)',
#   238: '13 dies de octubre (2015)',
#   239: '13 reasons why',
#   240: '13B (2009)',
#   241: '13th (2016)',
#   242: '13th Letter, The (1951)',
#   243: '13th Warrior, The (1999)',
#   244: '14 Blades (Jin yi wei) (2010)',
#   245: '14 Cameras (2018)',
#   246: '14 Going on 30 (1988)',
#   247: '14 Hours (Fourteen Hours) (1951)',
#   248: '14+ (2015)',
#   249: '1408 (2007)',
#   250: '1492: Conquest of Paradise (1992)',
#   251: '15 (2003)',
#   252: '15 (2005)',
#   253: '15 Février 1839 (2001)',
#   254: '15 Minutes (2001)',
#   255: '15 Minutes of War (2019)',
#   256: '15 Years and One Day (2013)',
#   257: '150 Milligrams (2016)',
#   258: '16 Acres (2012)',
#   259: '16 Blocks (2006)',
#   260: '16 Shots (2019)',
#   261: '16 Sunrises (2018)',
#   262: '16 Wishes (2010)',
#   263: '16 to Life (2009)',
#   264: '16-love (2012)',
#   265: '17 Again (2009)',
#   266: '170 Hz (2012)',
#   267: '1776 (1972)',
#   268: '1778 Stories of Me and My Wife (2011)',
#   269: '18 Again! (1988)',
#   270: '18 Meals (2011)',
#   271: '18 Year Old Virgin (2009)',
#   272: '18 Years Later (Diciotto anni dopo) (2010)',
#   273: "18 Years Old and Rising (J'aime regarder les filles) (2011)",
#   274: '1809-1810: mientras llega el día (2004)',
#   275: '180° South (180 Degrees South) (180° South: Conquerors of the Useless) (2010)',
#   276: '1812 (1912)',
#   277: '1812. Ballad of the Uhlans (2012)',
#   278: '186 Dollars to Freedom (2012)',
#   279: '187 (One Eight Seven) (1997)',
#   280: '1898. Los últimos de Filipinas (2016)',
#   281: '1900 (Novecento) (1976)',
#   282: '1911 (Xinhai geming) (2011)',
#   283: '1915 (2015)',
#   284: '1918 (1985)',
#   285: '1920 (2008)',
#   286: '1920: Evil Returns (2012)',
#   287: '1922 (2017)',
#   288: '1941 (1979)',
#   289: '1942: A Love Story (1994)',
#   290: '1944 (2015)',
#   291: '1945 (2017)',
#   292: '1945: The Savage Peace (2015)',
#   293: '1968 (2018)',
#   294: '1969 (1988)',
#   295: '1971 (2014)',
#   296: '1974: La posesión de Altair (2016)',
#   297: '1981 (2009)',
#   298: '1982 (2013)',
#   299: '1984 (1956)',
#   300: '1984 (Nineteen Eighty-Four) (1984)',
#   301: '1984 Revolution (2011)',
#   302: '1985 (2018)',
#   303: '1987 (2014)',
#   304: '1987: When the Day Comes (2017)',
#   305: '1989 (2014)',
#   306: '1990: The Bronx Warriors (1990: I guerrieri del Bronx) (1982)',
#   307: '1991 (2018)',
#   308: '1991: The Year Punk Broke (1992)',
#   309: '19th Wife, The (2010)',
#   310: '1:54 (2016)',
#   311: '1st Bite (2006)',
#   312: '1st Summoning (2019)',
#   313: '1st to Die (2003)',
#   314: '1½ Knights - In Search of the Ravishing Princess Herzelinde (2008)',
#   315: '2 (2007)',
#   316: '2 Autumns 3 Winters (2013)',
#   317: '2 Become 1 (Tin sun yut dui) (2006)',
#   318: '2 Bedroom 1 Bath (2014)',
#   319: '2 Cool 2 Be 4gotten (2016)',
#   320: '2 Countries (2015)',
#   321: '2 Days in New York (2012)',
#   322: '2 Days in Paris (2007)',
#   323: '2 Days in the Valley (1996)',
#   324: '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)',
#   325: '2 Guns (2013)',
#   326: '2 Hours (2012)',
#   327: '2 Jennifer (2016)',
#   328: '2 Lava 2 Lantula! (2016)',
#   329: '2 Nights Till Morning (2015)',
#   330: '2 Seconds (1998)',
#   331: '2 States (2014)',
#   332: '2 Young (2005)',
#   333: "2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her) (1967)",
#   334: '2 x 50 Years of French Cinema (1995)',
#   335: '2.0 (2018)',
#   336: '20 30 40 (2004)',
#   337: '20 Dates (1998)',
#   338: '20 Feet from Stardom (Twenty Feet from Stardom) (2013)',
#   339: '20 Fingers (2004)',
#   340: '20 Million Miles to Earth (1957)',
#   341: '20 Mule Team (1940)',
#   342: '20 Seconds of Joy (2007)',
#   343: '20 Weeks (2017)',
#   344: '20 Years After (2008)',
#   345: '20 Years Of Madness (2016)',
#   346: '20,000 Days on Earth (2014)',
#   347: '20,000 Leagues Under the Sea (1916)',
#   348: '20,000 Leagues Under the Sea (1954)',
#   349: '20,000 Years in Sing Sing (1932)',
#   350: '20.000 kisses (2013)',
#   351: '200 Cigarettes (1999)',
#   352: '200 Degrees (2017)',
#   353: '200 Motels (1971)',
#   354: '200 Pounds Beauty (2006)',
#   355: '2000 AD (2000)',
#   356: '2001 Maniacs (2005)',
#   357: '2001: A Space Odyssey (1968)',
#   358: '2001: A Space Travesty (2000)',
#   359: '2009: Lost Memories (2002)',
#   360: '2010: Moby Dick (2010)',
#   361: '2010: The Year We Make Contact (1984)',
#   362: '2012 (2009)',
#   363: '2012 Doomsday (2008)',
#   364: '2012: Ice Age (2011)',
#   365: '2012: Time for Change (2010)',
#   366: '2013 Rock and Roll Hall of Fame Induction Ceremony, The (2013)',
#   367: '2016 Oscar Nominated Short Films: Live Action (2016)',
#   368: "2016: Obama's America (2012)",
#   369: '2017 Oscar Nominated Short Films - Live Action (2017)',
#   370: '2019: After the Fall of New York (1983)',
#   371: '2020 Texas Gladiators (1983)',
#   372: '2033 (2010)',
#   373: '2036 Origin Unknown (2018)',
#   374: '2036: Nexus Dawn (2017)',
#   375: '2040 (2019)',
#   376: '2046 (2004)',
#   377: '2047 - Sights of Death (2014)',
#   378: '2048: Nowhere to Run (2017)',
#   379: '2084 (1984)',
#   380: '20th Century Boys - Chapter 1: Beginning of the End (2008)',
#   381: '20th Century Boys - Chapter 2: The Last Hope (2009)',
#   382: '20th Century Boys - Chapter 3: Our Flag (2009)',
#   383: '20th Century Oz (1976)',
#   384: '20th Century Women (2016)',
#   385: '21 (2008)',
#   386: '21 Bridges (2019)',
#   387: '21 Days (1940)',
#   388: '21 Days (2014)',
#   389: '21 Grams (2003)',
#   390: '21 Hours at Munich (1976)',
#   391: '21 Jump Street (2012)',
#   392: '21 Up (1977)',
#   393: '21 Years: Richard Linklater (2014)',
#   394: '21 and Over (2013)',
#   395: '21 nuits avec Pattie (2015)',
#   396: '21 tapaa pilata avioliitto (2013)',
#   397: '2103: The Deadly Wake (1997)',
#   398: '211 (2018)',
#   399: "22 Bullets (L'immortel) (2010)",
#   400: '22 Chaser (2018)',
#   401: '22 Female Kottayam (2012)',
#   402: '22 July (2018)',
#   403: '22 Jump Street (2014)',
#   404: '22 Minutes (2014)',
#   405: '22nd of May (2010)',
#   406: '23 (23 - Nichts ist so wie es scheint) (1998)',
#   407: '23 Blast (2014)',
#   408: '23 Minutes to Sunrise (2013)',
#   409: '23 Paces to Baker Street (1956)',
#   410: "2307: Winter's Dream (2016)",
#   411: '24 (2016)',
#   412: '24 7: Twenty Four Seven (1997)',
#   413: '24 City (Er shi si cheng ji) (2008)',
#   414: '24 Days (2014)',
#   415: '24 Exposures (2013)',
#   416: '24 Frames (2017)',
#   417: '24 Frames Per Second (1977)',
#   418: '24 Hour Party People (2002)',
#   419: '24 Hour Woman, The (1998)',
#   420: '24 Hours (1931)',
#   421: '24 Hours to Live (2017)',
#   422: '24 Weeks (2016)',
#   423: '24: Redemption (2008)',
#   424: '24th Day, The (2004)',
#   425: '24×36 (2016)',
#   426: '25 April (2015)',
#   427: '25 Carat (2008)',
#   428: "25 Fireman's Street (1973)",
#   429: '25 Watts (2001)',
#   430: '25 Ways to Quit Smoking (1989)',
#   431: '25 km/h (2018)',
#   432: '252: Signal of Life (2008)',
#   433: '25th Hour (2002)',
#   434: '26 Years (2012)',
#   435: '27 Club, The (2008)',
#   436: '27 Dresses (2008)',
#   437: '27 Missing Kisses (2000)',
#   438: '27: El club de los malditos (2018)',
#   439: '28 Days (2000)',
#   440: '28 Days Later (2002)',
#   441: '28 Hotel Rooms (2012)',
#   442: '28 Minutes for 3 Million Dollars (1967)',
#   443: '28 Up (1985)',
#   444: '28 Weeks Later (2007)',
#   445: '29+1 (2017)',
#   446: '29th Street (1991)',
#   447: '29th and Gay (2005)',
#   448: '2:13 (2009)',
#   449: '2:22 (2008)',
#   450: '2:22 (2017)',
#   451: '2:37 (2006)',
#   452: '2BPerfectlyHonest (2004)',
#   453: '2LDK (2003)',
#   454: '2gether (2000)',
#   455: '2nd Serve (2013)',
#   456: '3 A.M (2014)',
#   457: '3 A.M. (2001)',
#   458: '3 Avengers (1964)',
#   459: '3 Backyards (2010)',
#   460: '3 Bad Men (1926)',
#   461: '3 Beauties (2015)',
#   462: '3 Blind Mice (2003)',
#   463: '3 Days of Normal (2012)',
#   464: '3 Days to Kill (2014)',
#   465: '3 Extremes (Three... Extremes) (Saam gaang yi) (2004)',
#   466: '3 Faces (2018)',
#   467: '3 Geezers! (2013)',
#   468: '3 Godfathers (1948)',
#   469: '3 Hearts (2014)',
#   470: '3 Hours till Dead (2017)',
#   471: '3 Idiotas (2017)',
#   472: '3 Idiots (2009)',
#   473: '3 Lives (2019)',
#   474: '3 Men in White (1944)',
#   475: '3 Musketeers (2011)',
#   476: '3 Needles (2005)',
#   477: '3 Nights (2001)',
#   478: '3 Nights in the Desert (2015)',
#   479: '3 Ninjas (1992)',
#   480: '3 Ninjas Kick Back (1994)',
#   481: '3 Ninjas Knuckle Up (1995)',
#   482: '3 Ninjas: High Noon On Mega Mountain (1998)',
#   483: '3 Ring Circus (1954)',
#   484: '3 Rooms of Melancholia, The (Melancholian 3 huonetta) (2004)',
#   485: '3 Sailors and a Girl (Three Sailors and a Girl) (1953)',
#   486: '3 Simoa (2012)',
#   487: '3 Strikes (2000)',
#   488: '3 Times a Charm (2011)',
#   489: '3 Türken und ein Baby (2015)',
#   490: '3 Women (Three Women) (1977)',
#   491: '3 Worlds of Gulliver, The (1960)',
#   492: '3 from Hell (2019)',
#   493: '3 of a Kind (2012)',
#   494: '3 on a Couch (Three on a Couch) (1966)',
#   495: '3, 2, 1... Frankie Go Boom (Frankie Go Boom) (2012)',
#   496: '3-D Sex and Zen: Extreme Ecstasy (2011)',
#   497: '3-Day Weekend (2008)',
#   498: '3-Headed Shark Attack (2015)',
#   499: '3-Iron (Bin-jip) (2004)',
#   500: '3/4 (2017)',
#   501: '30 Beats (2012)',
#   502: "30 Days Until I'm Famous (2004)",
#   503: '30 Days of Night (2007)',
#   504: '30 Days of Night: Dark Days (2010)',
#   505: '30 Door Key (1991)',
#   506: '30 Is A Dangerous Age, Cynthia (1968)',
#   507: '30 Miles from Nowhere (2018)',
#   508: '30 Minutes or Less (2011)',
#   509: '30 Nights (2018)',
#   510: '30 Nights of Paranormal Activity With the Devil Inside the Girl With the Dragon Tattoo (2013)',
#   511: '30 Years to Life (1998)',
#   512: '30 Years to Life (2001)',
#   513: '300 (2007)',
#   514: '300 Miles to Heaven (300 Mil do Nieba) (1989)',
#   515: '300 Spartans, The (1962)',
#   516: '3000 Miles to Graceland (2001)',
#   517: '300: Rise of an Empire (2014)',
#   518: '301, 302 (301/302) (1995)',
#   519: '303 (2018)',
#   520: '305 (2008)',
#   521: '306 Hollywood (2018)',
#   522: '3096 Days (2013)',
#   523: '31 (2016)',
#   524: '31 North 62 East (2009)',
#   525: '31st of June (1978)',
#   526: '32A (2007)',
#   527: '33 Postcards (2011)',
#   528: '33 Scenes from Life (33 sceny z zycia) (2008)',
#   529: '35 Shots of Rum (35 rhums) (2008)',
#   530: '35 Up (1991)',
#   531: '36 (2012)',
#   532: '36 China Town (2006)',
#   533: '36 Chowringhee Lane (1981)',
#   534: '36 Hours (1965)',
#   535: '36 Quai des Orfèvres (Department 36) (2004)',
#   536: '36 Saints (2013)',
#   537: '36 Vayadhinile (2015)',
#   538: '36 fillette (1988)',
#   539: '360 (2011)',
#   540: '36th Chamber of Shaolin, The (Shao Lin san shi liu fang) (Master Killer) (1978)',
#   541: '37 (2014)',
#   542: '37 (2016)',
#   543: '37 Uses for a Dead Sheep (2006)',
#   544: '38 Parrots',
#   545: '3801 Lancaster: American Tragedy (2015)',
#   546: '388 Arletta Avenue (2011)',
#   547: '39 Steps, The (1935)',
#   548: '3: The Dale Earnhardt Story (2004)',
#   549: '3:10 to Yuma (1957)',
#   550: '3:10 to Yuma (2007)',
#   551: '3:15 (1985)',
#   552: '3faltig (2010)',
#   553: '3rd Night',
#   554: '3rd Voice, The (1960)',
#   555: '3rd World Hero (Bayaning Third World) (2000)',
#   556: '3some (Castillos de cartón) (2009)',
#   557: '3x3 (2009)',
#   558: '3x3 Eyes (1991)',
#   559: '3x3 Eyes: Legend of the Divine Demon (1995)',
#   560: '3½ Minutes, 10 Bullets (2015)',
#   561: '4 (2005)',
#   562: '4 Days (2017)',
#   563: '4 Days in May (2011)',
#   564: '4 Elements (2006)',
#   565: '4 Horror Tales - February 29 (2006)',
#   566: '4 Horror Tales - Hidden Floor (2006)',
#   567: '4 Horror Tales - Roommates (2006)',
#   568: '4 Horsemen of the Apocalypse, The (1962)',
#   569: '4 Little Girls (1997)',
#   570: '4 Minute Mile (2014)',
#   571: '4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile) (2007)',
#   572: '4 Moons (2014)',
#   573: '4 Wedding Planners (2011)',
#   574: '4 for Texas (1963)',
#   575: '4.1 Miles (2016)',
#   576: '4.3.2.1 (2010)',
#   577: '4/20 Massacre (2018)',
#   578: '40 (2009)',
#   579: '40 Carats (1973)',
#   580: '40 Days and 40 Nights (2002)',
#   581: '40 Days and Nights (2012)',
#   582: '40 Guns to Apache Pass (1967)',
#   583: '40 Minutes of Hell (2012)',
#   584: '40 Pounds of Trouble (1962)',
#   585: '40-Love (2014)',
#   586: '40-Year-Old Virgin, The (2005)',
#   587: '400 Blows, The (Les quatre cents coups) (1959)',
#   588: '400 Days (2015)',
#   589: '404: Error Not Found (2011)',
#   590: '405 (2000)',
#   591: '41 (2013)',
#   592: '42 (2013)',
#   593: '42 Grams (2017)',
#   594: '42 Up (1998)',
#   595: '42nd Street (1933)',
#   596: '438 Days (2019)',
#   597: '43: The Richard Petty Story (1972)',
#   598: '44 Inch Chest (2009)',
#   599: '44 Minutes: The North Hollywood Shoot-Out (2003)',
#   600: '44 Pages (2018)',
#   601: '44500 Max (2009)',
#   602: '45 Years (2015)',
#   603: '45365 (2010)',
#   604: '47 Meters Down (2016)',
#   605: '47 Meters Down: Uncaged (2019)',
#   606: '47 Ronin (2013)',
#   607: '47 Ronin, The (Genroku Chûshingura) (1941)',
#   608: '47 Samurai (Chûshingura) (Loyal 47 Ronin, The) (1962)',
#   609: '48 Christmas Wishes (2017)',
#   610: '48 Hrs. (1982)',
#   611: '48 Weeks Later (2006)',
#   612: '49 Up (2005)',
#   613: '49th Parallel (1941)',
#   614: '4:44 Last Day on Earth (2011)',
#   615: '4Closed (2013)',
#   616: '4D Man (1959)',
#   617: '4Got10 (2015)',
#   618: '4bia (2008)',
#   619: '4th Floor, The (1999)',
#   620: '4th Man Out (2016)',
#   621: '4th Man, The (Fourth Man, The) (Vierde man, De) (1983)',
#   622: '4th Period Mystery (2009)',
#   623: '4x4 (2019)',
#   624: '5 Against the House (1955)',
#   625: '5 Broken Cameras (2011)',
#   626: '5 Card Stud (1968)',
#   627: '5 Centimeters per Second (Byôsoku 5 senchimêtoru) (2007)',
#   628: '5 Days of War (2011)',
#   629: '5 Doctors (2016)',
#   630: "5 Dolls for an August Moon (5 bambole per la luna d'agosto) (1970)",
#   631: '5 Fingers (1952)',
#   632: '5 Flights Up (2014)',
#   633: '5 Headed Shark Attack (2017)',
#   634: '5 Hour Friends (2014)',
#   635: '5 Souls (2013)',
#   636: '5 Star Christmas (2018)',
#   637: '5 Steps to Danger (1957)',
#   638: '5 Sundarikal (2013)',
#   639: '5 in the Afternoon (2017)',
#   640: '5 to 7 (2014)',
#   641: '5,000 Fingers of Dr. T, The (1953)',
#   642: '50 Children: The Rescue Mission of Mr. And Mrs. Kraus (2013)',
#   643: '50 First Dates (2004)',
#   644: '50 Kilo Albaloo (2016)',
#   645: '50 Kisses (2014)',
#   646: '50 Million Frenchmen (1931)',
#   647: '50 Ways of Saying Fabulous (2005)',
#   648: '50 Ways to Leave Your Lover (2004)',
#   649: '50 Worst Movies Ever Made, The (2004)',
#   650: '50 to 1 (2014)',
#   651: '50/50 (2011)',
#   652: '500 MPH Storm (2013)',
#   653: '51 (2011)',
#   654: '51 Birch Street (2005)',
#   655: '51 Degrees North (2015)',
#   656: '51 Nevada (2018)',
#   657: "5150 Elm's Way (2009)",
#   658: '52 Pick-Up (1986)',
#   659: '52 Tuesdays (2014)',
#   660: '53 Wars (2018)',
#   661: '54 (1998)',
#   662: '54 Days (2014)',
#   663: '55 Days at Peking (1963)',
#   664: '55 Steps (2018)',
#   665: '56 Up (2012)',
#   666: '588 Rue Paradis (Mother) (1992)',
#   667: '5ive Days to Midnight (2004)',
#   668: '5th Day of Peace (Dio è con noi) (1969)',
#   669: '5th Musketeer, The (a.k.a. Fifth Musketeer, The) (1979)',
#   670: '5th Passenger (2018)',
#   671: '5th Street (2013)',
#   672: '5up 2down (Getting High) (5 Up 2 Down) (2006)',
#   673: '5x2 (2004)',
#   674: '6 Balloons (2018)',
#   675: '6 Below: Miracle on the Mountain (2017)',
#   676: '6 Days (2017)',
#   677: '6 Days to Air: The Making of South Park (2011)',
#   678: '6 Month Rule (Six Month Rule, The) (2011)',
#   679: '6 Points About Emma (2011)',
#   680: '6 Souls (Shelter) (2010)',
#   681: '6 Ways to Die (2015)',
#   682: '6 Years (2015)',
#   683: '6,000 Enemies (Six Thousand Enemies) (1939)',
#   684: '6-5=2 (2013)',
#   685: '6-Headed Shark Attack (2018)',
#   686: '6.5 Toman Per Meter (2019)',
#   687: '600 Miles (2015)',
#   688: '61* (2001)',
#   689: '616: Paranormal Incident (2013)',
#   690: '63 Up (2019)',
#   691: '633 Squadron (1964)',
#   692: '638 Ways to Kill Castro (2006)',
#   693: '64: Part 1 (2016)',
#   694: '64: Part 2 (2016)',
#   695: '65_RedRoses (2009)',
#   696: '66 Scenes From America (1982)',
#   697: '666 Revealed (2006)',
#   698: '666: The Beast (2007)',
#   699: '68 Kill (2017)',
#   700: '69 (2004)',
#   701: '6A',
#   702: '6ixtynin9 (Ruang Talok 69) (1999)',
#   703: '6th Day, The (2000)',
#   704: '6th Man, The (Sixth Man, The) (1997)',
#   705: '7 Boxes (2012)',
#   706: '7 Chinese Brothers (2015)',
#   707: '7 Days (Les 7 jours du talion) (2010)',
#   708: '7 Days in Entebbe (2018)',
#   709: '7 Days in Havana (2012)',
#   710: '7 Days in Hell (2015)',
#   711: '7 Days in September (2002)',
#   712: '7 Days of Himawari & Her Puppies (2013)',
#   713: '7 Dollars on the Red (Sette dollari sul rosso) (1966)',
#   714: '7 Dwarves: The Forest Is Not Enough (2006)',
#   715: '7 Emotions (2018)',
#   716: '7 Faces of Dr. Lao (1964)',
#   717: '7 Hours of Violence (1973)',
#   718: '7 Khoon Maaf (2011)',
#   719: '7 Kilos in 7 Days (1986)',
#   720: '7 Kocalı Hürmüz (2009)',
#   721: '7 Main Wishes (2013)',
#   722: '7 Men from Now (Seven Men from Now) (1956)',
#   723: '7 Minutes (2014)',
#   724: '7 Minutes (2016)',
#   725: '7 Nights Of Darkness (2011)',
#   726: '7 Plus Seven (1970)',
#   727: '7 Reasons to Run Away (from Society) (2019)',
#   728: '7 Rzeczy, Których Nie Wiecie o Facetach (2016)',
#   729: '7 Splinters in Time (2018)',
#   730: '7 Virgins (7 vírgenes) (2005)',
#   731: '7 Wise Dwarfs (1941)',
#   732: '7 Witches (2017)',
#   733: '7 Women (a.k.a. Seven Women) (1966)',
#   734: '7 Years (2006)',
#   735: '7 Years (2016)',
#   736: '7 and 8 (2007)',
#   737: '7 años de matrimonio (2013)',
#   738: '7 from Etheria (2017)',
#   739: '7 jours pas plus (2017)',
#   740: "7 monaci d'oro (1966)",
#   741: '7-Man Army (1976)',
#   742: '7.2 (2014)',
#   743: '700 Sundays (2014)',
#   744: '71 Fragments of a Chronology of Chance (71 Fragmente einer Chronologie des Zufalls) (1994)',
#   745: '711 Ocean Drive (1950)',
#   746: '713-й просит посадку (1961)',
#   747: '71: Into The Fire (Pohwasogeuro) (2010)',
#   748: '72 Meters (2004)',
#   749: '72 Tenants of Prosperity (2010)',
#   750: '7333 seconds of Johanna (2017)',
#   751: '7500 (2014)',
#   752: '76 (2016)',
#   753: '77 Minutes (2016)',
#   754: '78/52 (2017)',
#   755: '7:19 (2016)',
#   756: '7:35 in the Morning (2003)',
#   757: '7A (2018)',
#   758: '7G Rainbow Colony (2004)',
#   759: '7aam Arivu (2011)',
#   760: '7eventy 5ive (2007)',
#   761: '7th Cavalry (Seventh Cavalry) (1956)',
#   762: '7th Dawn, The (1964)',
#   763: '7th Floor (2013)',
#   764: '7th Heaven (Seventh Heaven) (1927)',
#   765: '7th Voyage of Sinbad, The (1958)',
#   766: '8 (2010)',
#   767: '8 1/2 (8½) (1963)',
#   768: '8 Bit Generation: The Commodore Wars (2016)',
#   769: '8 Dates (2008)',
#   770: '8 Diagram Pole Fighter, The (a.k.a. Invincible Pole Fighter) (Wu Lang ba gua gun) (1984)',
#   771: '8 First Dates (2012)',
#   772: '8 Heads in a Duffel Bag (1997)',
#   773: '8 Mile (2002)',
#   774: '8 Million Ways to Die (1986)',
#   775: '8 Minutes Idle (2014)',
#   776: '8 Murders a Day (2011)',
#   777: '8 New Dates (2015)',
#   778: '8 Remains (2018)',
#   779: '8 Seconds (1994)',
#   780: '8 Women (2002)',
#   781: '8 X 10 Tasveer (2009)',
#   782: '8 ½ $ (1999)',
#   783: '8 ½ Women (a.k.a. 8 1/2 Women) (a.k.a. Eight and a Half Women) (1999)',
#   784: '8-Ball (8-pallo) (2013)',
#   785: '80 Milionów (2011)',
#   786: '80 Minutes (2008)',
#   787: '80 Steps to Jonah (1969)',
#   788: '80,000 Suspects (1963)',
#   789: '800 Bullets (800 Balas) (2002)',
#   790: '808 (2015)',
#   791: '8213: Gacy House (2010)',
#   792: '84 Charing Cross Road (1987)',
#   793: '84 Charlie Mopic (1989)',
#   794: '88 (2015)',
#   795: '88 Minutes (2008)',
#   796: '8: The Mormon Proposition (2010)',
#   797: '8:46 (2011)',
#   798: '8MM (1999)',
#   799: '8MM 2 (2005)',
#   800: '8th Wonderland (2008)',
#   801: '9 (2005)',
#   802: '9 (2009)',
#   803: '9 1/2 Weeks (Nine 1/2 Weeks) (1986)',
#   804: '9 Dalmuir West (1962)',
#   805: '9 Fingers (2018)',
#   806: '9 Full Moons (2013)',
#   807: '9 Satra (2018)',
#   808: '9 Songs (2004)',
#   809: '9 Souls (Nain souruzu) (2003)',
#   810: '9 Star Hotel (Malon 9 Kochavim) (2007)',
#   811: '9 Variations on a Dance Theme (1967)',
#   812: '9-Man (2014)',
#   813: '9.79* (2012)',
#   814: '9/11 (2002)',
#   815: '9/11 (2017)',
#   816: '9/11: The Falling Man (2006)',
#   817: '90 Minutes (90 minutter) (2012)',
#   818: '90 Minutes in Heaven (2015)',
#   819: '90° South (1933)',
#   820: '911 Nightmare (2016)',
#   821: '911: The Road to Tyranny (2002)',
#   822: '93 Days (2016)',
#   823: '95 (2017)',
#   824: '95 Miles to Go (2006)',
#   825: '9500 Liberty (2009)',
#   826: '95ers: Time Runners (2013)',
#   827: '96 (2018)',
#   828: '96 Minutes (2011) ',
#   829: '964 Pinocchio (1991)',
#   830: '97% Owned (2012)',
#   831: '976-EVIL (1989)',
#   832: '976-EVIL II (1992)',
#   833: '977 (2006)',
#   834: '984: Prisoner of the Future (1982)',
#   835: '99 (2009)',
#   836: '99 Dizengoff Street (1979)',
#   837: '99 Homes (2014)',
#   838: '99 River Street (1953)',
#   839: '99 and 44/100% Dead (1974)',
#   840: '99 francs (2007)',
#   841: '9th Company (2005)',
#   842: '9to5: Days in Porn (a.k.a. 9 to 5: Days in Porn) (2008)',
#   843: 'A (1998)',
#   844: 'A 2nd Chance (2013)',
#   845: 'A Bad Idea Gone Wrong (2017)',
#   846: 'A Bad Moms Christmas (2017)',
#   847: 'A Bag of Marbles (2017)',
#   848: 'A Bagful of Fleas (1962)',
#   849: 'A Barefoot Dream (2010)',
#   850: 'A Beautiful Demon: Kazuo Koike on Lady Snowblood (2016)',
#   851: 'A Beautiful Planet (2016)',
#   852: 'A Bee in the Rain (1972)',
#   853: "A Beginner's Guide to Snuff (2016)",
#   854: 'A Bela e o Paparazzo (2010)',
#   855: 'A Bell From Hell (1973)',
#   856: 'A Better Tomorrow (2018)',
#   857: 'A Bill of Divorcement (1932)',
#   858: 'A Billion Lives (2016)',
#   859: 'A Black Ribbon for Deborah (1974)',
#   860: 'A Black Rose Is an Emblem of Sorrow, a Red Rose an Emblem of Love (1989)',
#   861: 'A Black Veil for Lisa (1968)',
#   862: 'A Blade in the Dark (1983)',
#   863: 'A Blank on the Map (1971)',
#   864: 'A Blood Pledge (2009)',
#   865: 'A Bloody Aria (2006)',
#   866: 'A Blue Automobile (2004)',
#   867: 'A Bluebird in My Heart (2018)',
#   868: 'A Body to Die For: The Aaron Henry Story (1994)',
#   869: 'A Bomb Was Stolen (1961)',
#   870: 'A Boring Story (1983)',
#   871: 'A Borrowed Life (1994)',
#   872: 'A Bottle in the Gaza Sea (2012)',
#   873: 'A Boy Called Po (2016)',
#   874: 'A Boy Called Sailboat (2018)',
#   875: 'A Boy and His Samurai (2010)',
#   876: 'A Boy from Calabria (1987)',
#   877: 'A Boy. A Girl. A Dream: Love on Election Night (2018)',
#   878: 'A Boyfriend for Christmas (2004)',
#   879: 'A Boyfriend for My Wife (2008)',
#   880: 'A Brand New Life (2009)',
#   881: 'A Brave Heart: The Lizzie Velasquez Story (2015)',
#   882: 'A Bread Factory Part One: For the Sake of Gold (2018)',
#   883: 'A Bread Factory Part Two: Walk with Me a While (2018)',
#   884: 'A Bride for Christmas (2012)',
#   885: 'A Bride for Henry (1937)',
#   886: 'A Bride for Rip Van Winkle (2016)',
#   887: 'A Brief Season (1969)',
#   888: 'A Bright Shining Lie (1998)',
#   889: 'A Brilliant Madness (2002)',
#   890: 'A Brokedown Melody (2004)',
#   891: 'A Bronx Morning (1931)',
#   892: 'A Brother (2018)',
#   893: "A Brother's Love (2019)",
#   894: 'A Bucket of Blood (1995)',
#   895: 'A Buddha (2005)',
#   896: 'A Bullet for Pretty Boy (1970)',
#   897: 'A Bullet for Sandoval (1969)',
#   898: 'A Bullet for a Stranger (1971)',
#   899: "A Bunny's Tale (1985)",
#   900: 'A Busy Day (1914)',
#   901: 'A Cage of Nightingales (1945)',
#   902: 'A Call to Remember (1997)',
#   903: 'A Carne é Fraca (2004)',
#   904: 'A Castle Within a Castle (1955)',
#   905: 'A Castle in Italy (2013)',
#   906: 'A Chairy Tale (1957)',
#   907: 'A Chance of Snow (1998)',
#   908: 'A Change of Place (1994)',
#   909: 'A Change of Seasons (1980)',
#   910: 'A Charlie Brown Thanksgiving (1973)',
#   911: 'A Cheerful Gang Turns the Earth (2006)',
#   912: 'A Chinese Ghost Story (2011)',
#   913: 'A Chinese Ghost Story III (1991)',
#   914: "A Chinese Odyssey Part One: Pandora's Box (1995)",
#   915: 'A Chinese Odyssey Part Two: Cinderella (1995)',
#   916: 'A Chinese in a Coma (2000)',
#   917: 'A Christmas Carol (1954)',
#   918: 'A Christmas Carol (2015)',
#   919: 'A Christmas Detour (2015)',
#   920: 'A Christmas Eve Miracle (2015)',
#   921: 'A Christmas Horror Story (2015)',
#   922: 'A Christmas Kiss (2011)',
#   923: 'A Christmas Kiss II (2014)',
#   924: 'A Christmas Melody (2015)',
#   925: 'A Christmas Memory (1966)',
#   926: 'A Christmas Prince (2017)',
#   927: 'A Christmas Prince: The Royal Wedding (2018)',
#   928: 'A Christmas Romance (1994)',
#   929: 'A Christmas Story Live! (2017)',
#   930: 'A Christmas Tree Miracle (2013)',
#   931: 'A Christmas Visitor (2002)',
#   932: 'A Christmas Wedding Tail (2011)',
#   933: 'A Christmas Wish (2011)',
#   934: 'A Christmas for the Books (2018)',
#   935: 'A Ciambra (2017)',
#   936: 'A Cinderella Christmas (2016)',
#   937: 'A Cinderella Story: Christmas Wish (2019)',
#   938: 'A Cinderella Story: If the Shoe Fits (2016)',
#   939: 'A Cinderella Story: Once Upon a Song (2011)',
#   940: 'A City of Sadness (1989)',
#   941: 'A Colbert Christmas: The Greatest Gift of All! (2008)',
#   942: "A Cold Night's Death (1973)",
#   943: 'A Colony (2019)',
#   944: 'A Colour Box (1935)',
#   945: 'A Coming-Out Party (1961)',
#   946: 'A Company Man (2012)',
#   947: "A Connecticut Yankee in King Arthur's Court (1949)",
#   948: "A Connecticut Yankee in King Arthur's Court (1970)",
#   949: "A Connecticut Yankee in King Arthur's Court (1989)",
#   950: 'A Conspiracy of Faith (2016)',
#   951: 'A Constant Forge (2000)',
#   952: 'A Cookie Cutter Christmas (2014)',
#   953: 'A Cool Fish (2018)',
#   954: 'A Cooler Climate (1999)',
#   955: 'A Corner in Wheat (1909)',
#   956: 'A Cosmic Christmas (1977)',
#   957: 'A Country Called Home (2015)',
#   958: 'A Country Wedding (2015)',
#   959: 'A Covenant with Death (1967)',
#   960: 'A Cowboy Needs A Horse (1956)',
#   961: 'A Crack in the Floor (2000)',
#   962: 'A Crimson Man (2017)',
#   963: 'A Crooked Somebody (2017)',
#   964: 'A Crude Awakening (2006)',
#   965: 'A Crush on You (2011)',
#   966: 'A Cry in the Wild (1990)',
#   967: 'A Cry in the Wilderness (1974)',
#   968: 'A Cure for Wellness (2017)',
#   969: 'A Curtain Raiser (2006)',
#   970: 'A Dandy in Aspic (1968)',
#   971: 'A Dangerous Game (2014)',
#   972: 'A Dangerous Man: Lawrence After Arabia (1992)',
#   973: 'A Dangerous Place (1995)',
#   974: 'A Dangerous Son (2018)',
#   975: 'A Dark Place Inside',
#   976: 'A Dark Song (2017)',
#   977: 'A Dash of Love (2017)',
#   978: 'A Date for Mad Mary (2016)',
#   979: 'A Date in 2025 (2017)',
#   980: 'A Date with Miss Fortune (2015)',
#   981: 'A Date with the Falcon (1942)',
#   982: 'A Daughter Of Destiny (1928)',
#   983: "A Daughter's Nightmare (2014)",
#   984: 'A Day (2017)',
#   985: 'A Day at the Beach (1972)',
#   986: 'A Day in Court (1953)',
#   987: 'A Day in the Death of Joe Egg (1972)',
#   988: 'A Deadly Adoption (2015)',
#   989: 'A Deadly Obsession (2012)',
#   990: 'A Deal With The Universe (2019)',
#   991: 'A Death in the Gunj (2016)',
#   992: 'A December Bride (2016)',
#   993: 'A Decent Life (1979)',
#   994: 'A Decent Man (2016)',
#   995: 'A Demon Within (2017)',
#   996: 'A Different Kind of Christmas (1996)',
#   997: 'A Different Loyalty (2004)',
#   998: 'A Different Story (1978)',
#   999: 'A Difficult Life (1961)',
#   ...},
#  'genres': {0: '(no genres listed)',
#   1: 'Action',
#   2: 'Action|Adventure',
#   3: 'Action|Adventure|Animation',
#   4: 'Action|Adventure|Animation|Children',
#   5: 'Action|Adventure|Animation|Children|Comedy',
#   6: 'Action|Adventure|Animation|Children|Comedy|Fantasy',
#   7: 'Action|Adventure|Animation|Children|Comedy|IMAX',
#   8: 'Action|Adventure|Animation|Children|Comedy|Romance',
#   9: 'Action|Adventure|Animation|Children|Comedy|Sci-Fi',
#   10: 'Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX',
#   11: 'Action|Adventure|Animation|Children|Comedy|Western',
#   12: 'Action|Adventure|Animation|Children|Crime|Mystery',
#   13: 'Action|Adventure|Animation|Children|Drama',
#   14: 'Action|Adventure|Animation|Children|Fantasy',
#   15: 'Action|Adventure|Animation|Children|Fantasy|Sci-Fi',
#   16: 'Action|Adventure|Animation|Children|Mystery',
#   17: 'Action|Adventure|Animation|Children|Sci-Fi',
#   18: 'Action|Adventure|Animation|Comedy',
#   19: 'Action|Adventure|Animation|Comedy|Crime|Mystery',
#   20: 'Action|Adventure|Animation|Comedy|Drama|Fantasy|Romance',
#   21: 'Action|Adventure|Animation|Comedy|Fantasy',
#   22: 'Action|Adventure|Animation|Comedy|Fantasy|Mystery|Sci-Fi',
#   23: 'Action|Adventure|Animation|Comedy|Sci-Fi',
#   24: 'Action|Adventure|Animation|Comedy|Thriller',
#   25: 'Action|Adventure|Animation|Crime',
#   26: 'Action|Adventure|Animation|Crime|Fantasy',
#   27: 'Action|Adventure|Animation|Drama',
#   28: 'Action|Adventure|Animation|Drama|Fantasy',
#   29: 'Action|Adventure|Animation|Drama|Fantasy|Sci-Fi',
#   30: 'Action|Adventure|Animation|Drama|Romance',
#   31: 'Action|Adventure|Animation|Drama|Sci-Fi',
#   32: 'Action|Adventure|Animation|Drama|Sci-Fi|War',
#   33: 'Action|Adventure|Animation|Fantasy',
#   34: 'Action|Adventure|Animation|Fantasy|Horror',
#   35: 'Action|Adventure|Animation|Fantasy|IMAX',
#   36: 'Action|Adventure|Animation|Fantasy|Sci-Fi',
#   37: 'Action|Adventure|Animation|Horror',
#   38: 'Action|Adventure|Animation|Horror|Sci-Fi',
#   39: 'Action|Adventure|Animation|Mystery|Sci-Fi',
#   40: 'Action|Adventure|Animation|Sci-Fi',
#   41: 'Action|Adventure|Animation|Sci-Fi|Thriller',
#   42: 'Action|Adventure|Children',
#   43: 'Action|Adventure|Children|Comedy',
#   44: 'Action|Adventure|Children|Comedy|Crime',
#   45: 'Action|Adventure|Children|Comedy|Fantasy',
#   46: 'Action|Adventure|Children|Comedy|Fantasy|Sci-Fi',
#   47: 'Action|Adventure|Children|Comedy|Mystery',
#   48: 'Action|Adventure|Children|Comedy|Romance',
#   49: 'Action|Adventure|Children|Comedy|Sci-Fi',
#   50: 'Action|Adventure|Children|Crime|Mystery|Thriller',
#   51: 'Action|Adventure|Children|Drama',
#   52: 'Action|Adventure|Children|Drama|Fantasy',
#   53: 'Action|Adventure|Children|Drama|Fantasy|Sci-Fi',
#   54: 'Action|Adventure|Children|Drama|Western',
#   55: 'Action|Adventure|Children|Fantasy',
#   56: 'Action|Adventure|Children|Fantasy|Mystery|Thriller',
#   57: 'Action|Adventure|Children|Fantasy|Sci-Fi',
#   58: 'Action|Adventure|Children|IMAX',
#   59: 'Action|Adventure|Children|Mystery|Sci-Fi',
#   60: 'Action|Adventure|Children|Romance',
#   61: 'Action|Adventure|Children|Sci-Fi',
#   62: 'Action|Adventure|Comedy',
#   63: 'Action|Adventure|Comedy|Crime',
#   64: 'Action|Adventure|Comedy|Crime|Drama',
#   65: 'Action|Adventure|Comedy|Crime|Drama|Film-Noir|Horror|Mystery|Thriller|Western',
#   66: 'Action|Adventure|Comedy|Crime|Drama|Romance|Thriller',
#   67: 'Action|Adventure|Comedy|Crime|Drama|Thriller',
#   68: 'Action|Adventure|Comedy|Crime|Drama|War',
#   69: 'Action|Adventure|Comedy|Crime|Fantasy',
#   70: 'Action|Adventure|Comedy|Crime|Mystery|Romance',
#   71: 'Action|Adventure|Comedy|Crime|Mystery|Thriller',
#   72: 'Action|Adventure|Comedy|Crime|Romance|Thriller',
#   73: 'Action|Adventure|Comedy|Crime|Sci-Fi',
#   74: 'Action|Adventure|Comedy|Crime|Thriller',
#   75: 'Action|Adventure|Comedy|Crime|Thriller|War',
#   76: 'Action|Adventure|Comedy|Documentary|Fantasy',
#   77: 'Action|Adventure|Comedy|Drama',
#   78: 'Action|Adventure|Comedy|Drama|Fantasy|Thriller',
#   79: 'Action|Adventure|Comedy|Drama|Horror',
#   80: 'Action|Adventure|Comedy|Drama|Mystery|Romance|Thriller',
#   81: 'Action|Adventure|Comedy|Drama|Romance',
#   82: 'Action|Adventure|Comedy|Drama|Romance|Thriller',
#   83: 'Action|Adventure|Comedy|Drama|Romance|War',
#   84: 'Action|Adventure|Comedy|Drama|Romance|Western',
#   85: 'Action|Adventure|Comedy|Drama|Thriller',
#   86: 'Action|Adventure|Comedy|Drama|War',
#   87: 'Action|Adventure|Comedy|Fantasy',
#   88: 'Action|Adventure|Comedy|Fantasy|Horror',
#   89: 'Action|Adventure|Comedy|Fantasy|Horror|Sci-Fi',
#   90: 'Action|Adventure|Comedy|Fantasy|Horror|Thriller',
#   91: 'Action|Adventure|Comedy|Fantasy|Mystery',
#   92: 'Action|Adventure|Comedy|Fantasy|Romance',
#   93: 'Action|Adventure|Comedy|Fantasy|Sci-Fi',
#   94: 'Action|Adventure|Comedy|Fantasy|Sci-Fi|Thriller',
#   95: 'Action|Adventure|Comedy|Horror',
#   96: 'Action|Adventure|Comedy|Horror|Sci-Fi|Thriller',
#   97: 'Action|Adventure|Comedy|Horror|Thriller',
#   98: 'Action|Adventure|Comedy|Musical|Romance|Thriller',
#   99: 'Action|Adventure|Comedy|Mystery',
#   100: 'Action|Adventure|Comedy|Mystery|Romance',
#   101: 'Action|Adventure|Comedy|Romance',
#   102: 'Action|Adventure|Comedy|Romance|Thriller',
#   103: 'Action|Adventure|Comedy|Romance|War',
#   104: 'Action|Adventure|Comedy|Sci-Fi',
#   105: 'Action|Adventure|Comedy|Sci-Fi|IMAX',
#   106: 'Action|Adventure|Comedy|Sci-Fi|Thriller',
#   107: 'Action|Adventure|Comedy|Thriller',
#   108: 'Action|Adventure|Comedy|War',
#   109: 'Action|Adventure|Comedy|War|Western',
#   110: 'Action|Adventure|Comedy|Western',
#   111: 'Action|Adventure|Crime',
#   112: 'Action|Adventure|Crime|Drama',
#   113: 'Action|Adventure|Crime|Drama|Fantasy|Horror|Mystery',
#   114: 'Action|Adventure|Crime|Drama|Mystery',
#   115: 'Action|Adventure|Crime|Drama|Mystery|Thriller',
#   116: 'Action|Adventure|Crime|Drama|Romance',
#   117: 'Action|Adventure|Crime|Drama|Romance|Thriller',
#   118: 'Action|Adventure|Crime|Drama|Sci-Fi',
#   119: 'Action|Adventure|Crime|Drama|Sci-Fi|Thriller|War',
#   120: 'Action|Adventure|Crime|Drama|Thriller',
#   121: 'Action|Adventure|Crime|Drama|Thriller|War',
#   122: 'Action|Adventure|Crime|Drama|Western',
#   123: 'Action|Adventure|Crime|Fantasy',
#   124: 'Action|Adventure|Crime|Film-Noir|Romance',
#   125: 'Action|Adventure|Crime|Horror',
#   126: 'Action|Adventure|Crime|Horror|Sci-Fi',
#   127: 'Action|Adventure|Crime|Horror|Thriller',
#   128: 'Action|Adventure|Crime|IMAX',
#   129: 'Action|Adventure|Crime|Mystery',
#   130: 'Action|Adventure|Crime|Mystery|Romance',
#   131: 'Action|Adventure|Crime|Mystery|Thriller',
#   132: 'Action|Adventure|Crime|Romance',
#   133: 'Action|Adventure|Crime|Romance|Western',
#   134: 'Action|Adventure|Crime|Sci-Fi',
#   135: 'Action|Adventure|Crime|Sci-Fi|Thriller',
#   136: 'Action|Adventure|Crime|Thriller',
#   137: 'Action|Adventure|Crime|War',
#   138: 'Action|Adventure|Crime|Western',
#   139: 'Action|Adventure|Documentary',
#   140: 'Action|Adventure|Documentary|Drama',
#   141: 'Action|Adventure|Documentary|Drama|Thriller|Western',
#   142: 'Action|Adventure|Drama',
#   143: 'Action|Adventure|Drama|Fantasy',
#   144: 'Action|Adventure|Drama|Fantasy|Horror|Romance|Sci-Fi',
#   145: 'Action|Adventure|Drama|Fantasy|IMAX',
#   146: 'Action|Adventure|Drama|Fantasy|Mystery',
#   147: 'Action|Adventure|Drama|Fantasy|Mystery|IMAX',
#   148: 'Action|Adventure|Drama|Fantasy|Romance',
#   149: 'Action|Adventure|Drama|Fantasy|Romance|Sci-Fi|Thriller',
#   150: 'Action|Adventure|Drama|Fantasy|Sci-Fi|Thriller',
#   151: 'Action|Adventure|Drama|Fantasy|Thriller',
#   152: 'Action|Adventure|Drama|Horror|Sci-Fi',
#   153: 'Action|Adventure|Drama|Horror|Thriller',
#   154: 'Action|Adventure|Drama|IMAX',
#   155: 'Action|Adventure|Drama|Musical|Romance|Thriller|War',
#   156: 'Action|Adventure|Drama|Mystery',
#   157: 'Action|Adventure|Drama|Mystery|Thriller',
#   158: 'Action|Adventure|Drama|Romance',
#   159: 'Action|Adventure|Drama|Romance|Thriller',
#   160: 'Action|Adventure|Drama|Romance|Thriller|Western',
#   161: 'Action|Adventure|Drama|Romance|War',
#   162: 'Action|Adventure|Drama|Romance|Western',
#   163: 'Action|Adventure|Drama|Sci-Fi',
#   164: 'Action|Adventure|Drama|Sci-Fi|Thriller',
#   165: 'Action|Adventure|Drama|Thriller',
#   166: 'Action|Adventure|Drama|Thriller|IMAX',
#   167: 'Action|Adventure|Drama|Thriller|War',
#   168: 'Action|Adventure|Drama|Thriller|Western',
#   169: 'Action|Adventure|Drama|War',
#   170: 'Action|Adventure|Drama|War|Western',
#   171: 'Action|Adventure|Drama|Western',
#   172: 'Action|Adventure|Fantasy',
#   173: 'Action|Adventure|Fantasy|Horror',
#   174: 'Action|Adventure|Fantasy|Horror|Sci-Fi',
#   175: 'Action|Adventure|Fantasy|Horror|Sci-Fi|Thriller',
#   176: 'Action|Adventure|Fantasy|Horror|Thriller',
#   177: 'Action|Adventure|Fantasy|IMAX',
#   178: 'Action|Adventure|Fantasy|Musical',
#   179: 'Action|Adventure|Fantasy|Musical|Romance',
#   180: 'Action|Adventure|Fantasy|Mystery',
#   181: 'Action|Adventure|Fantasy|Mystery|Sci-Fi',
#   182: 'Action|Adventure|Fantasy|Romance',
#   183: 'Action|Adventure|Fantasy|Romance|IMAX',
#   184: 'Action|Adventure|Fantasy|Romance|Sci-Fi',
#   185: 'Action|Adventure|Fantasy|Sci-Fi',
#   186: 'Action|Adventure|Fantasy|Sci-Fi|IMAX',
#   187: 'Action|Adventure|Fantasy|Sci-Fi|Thriller',
#   188: 'Action|Adventure|Fantasy|Thriller',
#   189: 'Action|Adventure|Fantasy|War',
#   190: 'Action|Adventure|Film-Noir|Thriller|War',
#   191: 'Action|Adventure|Horror',
#   192: 'Action|Adventure|Horror|Mystery',
#   193: 'Action|Adventure|Horror|Mystery|Sci-Fi|Thriller',
#   194: 'Action|Adventure|Horror|Sci-Fi',
#   195: 'Action|Adventure|Horror|Sci-Fi|Thriller',
#   196: 'Action|Adventure|Horror|Thriller',
#   197: 'Action|Adventure|IMAX',
#   198: 'Action|Adventure|Mystery',
#   199: 'Action|Adventure|Mystery|Romance',
#   200: 'Action|Adventure|Mystery|Romance|Thriller',
#   201: 'Action|Adventure|Mystery|Sci-Fi',
#   202: 'Action|Adventure|Mystery|Sci-Fi|Thriller',
#   203: 'Action|Adventure|Mystery|Thriller',
#   204: 'Action|Adventure|Romance',
#   205: 'Action|Adventure|Romance|Sci-Fi',
#   206: 'Action|Adventure|Romance|Thriller',
#   207: 'Action|Adventure|Romance|War',
#   208: 'Action|Adventure|Romance|Western',
#   209: 'Action|Adventure|Sci-Fi',
#   210: 'Action|Adventure|Sci-Fi|IMAX',
#   211: 'Action|Adventure|Sci-Fi|Thriller',
#   212: 'Action|Adventure|Sci-Fi|Thriller|IMAX',
#   213: 'Action|Adventure|Sci-Fi|Thriller|War',
#   214: 'Action|Adventure|Sci-Fi|War|IMAX',
#   215: 'Action|Adventure|Sci-Fi|Western',
#   216: 'Action|Adventure|Thriller',
#   217: 'Action|Adventure|Thriller|IMAX',
#   218: 'Action|Adventure|Thriller|War',
#   219: 'Action|Adventure|Thriller|Western',
#   220: 'Action|Adventure|War',
#   221: 'Action|Adventure|War|Western',
#   222: 'Action|Adventure|Western',
#   223: 'Action|Adventure|Western|IMAX',
#   224: 'Action|Animation',
#   225: 'Action|Animation|Children',
#   226: 'Action|Animation|Children|Comedy',
#   227: 'Action|Animation|Children|Comedy|Fantasy',
#   228: 'Action|Animation|Children|Comedy|IMAX',
#   229: 'Action|Animation|Children|Comedy|Sci-Fi',
#   230: 'Action|Animation|Children|Comedy|Sci-Fi|IMAX',
#   231: 'Action|Animation|Children|Crime',
#   232: 'Action|Animation|Children|Fantasy',
#   233: 'Action|Animation|Children|Fantasy|Sci-Fi',
#   234: 'Action|Animation|Children|Sci-Fi',
#   235: 'Action|Animation|Comedy',
#   236: 'Action|Animation|Comedy|Crime|Drama|Romance|Thriller',
#   237: 'Action|Animation|Comedy|Fantasy',
#   238: 'Action|Animation|Comedy|Fantasy|Horror|Sci-Fi',
#   239: 'Action|Animation|Comedy|Horror|Mystery|Thriller',
#   240: 'Action|Animation|Comedy|Horror|Thriller',
#   241: 'Action|Animation|Comedy|Romance',
#   242: 'Action|Animation|Comedy|Romance|Western',
#   243: 'Action|Animation|Comedy|Sci-Fi',
#   244: 'Action|Animation|Comedy|Thriller',
#   245: 'Action|Animation|Crime',
#   246: 'Action|Animation|Crime|Drama',
#   247: 'Action|Animation|Crime|Drama|Mystery',
#   248: 'Action|Animation|Crime|Horror|Sci-Fi',
#   249: 'Action|Animation|Crime|Mystery',
#   250: 'Action|Animation|Crime|Sci-Fi',
#   251: 'Action|Animation|Crime|Sci-Fi|Thriller',
#   252: 'Action|Animation|Crime|Thriller',
#   253: 'Action|Animation|Drama',
#   254: 'Action|Animation|Drama|Fantasy|Horror',
#   255: 'Action|Animation|Drama|Fantasy|Sci-Fi',
#   256: 'Action|Animation|Drama|Horror|Sci-Fi',
#   257: 'Action|Animation|Drama|Mystery',
#   258: 'Action|Animation|Drama|Sci-Fi',
#   259: 'Action|Animation|Drama|Sci-Fi|Thriller',
#   260: 'Action|Animation|Drama|Thriller',
#   261: 'Action|Animation|Drama|War',
#   262: 'Action|Animation|Fantasy',
#   263: 'Action|Animation|Fantasy|Horror',
#   264: 'Action|Animation|Fantasy|Horror|Sci-Fi|Thriller',
#   265: 'Action|Animation|Fantasy|IMAX',
#   266: 'Action|Animation|Fantasy|Sci-Fi',
#   267: 'Action|Animation|Fantasy|Sci-Fi|Thriller',
#   268: 'Action|Animation|Film-Noir|Sci-Fi|Thriller',
#   269: 'Action|Animation|Horror',
#   270: 'Action|Animation|Horror|Mystery',
#   271: 'Action|Animation|Horror|Sci-Fi',
#   272: 'Action|Animation|Horror|Thriller',
#   273: 'Action|Animation|Mystery',
#   274: 'Action|Animation|Mystery|IMAX',
#   275: 'Action|Animation|Romance',
#   276: 'Action|Animation|Sci-Fi',
#   277: 'Action|Animation|Sci-Fi|Thriller',
# ...
#   305: '13.01.06',
#   306: '1300s',
#   307: '1304',
#   308: '1305',
#   309: '13th Century',
#   310: '13th century',
#   311: '14 year gap',
#   312: '14-10-2007',
#   313: '14-12-2006',
#   314: '14-2-2007',
#   315: '14.01.06',
#   316: '14.06.06',
#   317: '14.07.06',
#   318: '143',
#   319: '14th Century',
#   320: '14th century',
#   321: '15 minute long flashback scene',
#   322: '15.01.06',
#   323: '15.02.06',
#   324: '1538',
#   325: '15555555555',
#   326: '1587',
#   327: '15th Century',
#   328: '15th century',
#   329: '16 Nic cages',
#   330: '16-year-old',
#   331: '16.01.06',
#   332: '1600s',
#   333: '16mm',
#   334: '16th century',
#   335: '17-1-2008',
#   336: "1700's",
#   337: '1700s',
#   338: '1753',
#   339: '1790s',
#   340: '17th century',
#   341: '17th century America',
#   342: '18 wheeler',
#   343: '18+',
#   344: '18-11-2006',
#   345: '18.01.06',
#   346: '18.03.06',
#   347: "1800's",
#   348: '1800s',
#   349: '1820s',
#   350: '1840s',
#   351: "1860's",
#   352: '1860s',
#   353: '1863',
#   354: '1870s',
#   355: '1871',
#   356: '1877',
#   357: '1890s',
#   358: '18th Century',
#   359: '18th Century Russia',
#   360: '18th century',
#   361: '19 century',
#   362: '19-8-2007',
#   363: '19.01.06',
#   364: '19.02.06',
#   365: '1900',
#   366: "1900's",
#   367: '1900s',
#   368: '1905 Revolution',
#   369: '1910s',
#   370: '1918',
#   371: '1920',
#   372: "1920's",
#   373: '1920s',
#   374: '1922',
#   375: '1926',
#   376: '1929',
#   377: "1930's",
#   378: '1930s',
#   379: '1930ties',
#   380: '1932',
#   381: '1935',
#   382: '1936',
#   383: '1938',
#   384: '1939',
#   385: '1940',
#   386: "1940's",
#   387: "1940's feel",
#   388: '1940s',
#   389: '1941',
#   390: '1942',
#   391: '1943',
#   392: '1947',
#   393: '1950',
#   394: "1950's",
#   395: "1950's Production",
#   396: '1950s',
#   397: '1950s housewives',
#   398: '1950s society',
#   399: '1951 Academy Award for Special Effects',
#   400: '1955',
#   401: '1957',
#   402: '1958',
#   403: '1959',
#   404: '1960',
#   405: "1960's",
#   406: "1960's Jim Crow",
#   407: '1960s',
#   408: '1960s Tokyo',
#   409: '1960s aesthetics',
#   410: '1960s fashion',
#   411: '1963',
#   412: '1964',
#   413: '1965',
#   414: '1965 Cannes',
#   415: '1966',
#   416: '1968',
#   417: '1969',
#   418: '1970',
#   419: "1970's",
#   420: '1970s',
#   421: '1970s humour',
#   422: '1970s period piece',
#   423: '1976',
#   424: '1977',
#   425: '1978',
#   426: '1979',
#   427: '1980',
#   428: "1980's",
#   429: "1980's cult",
#   430: '1980s',
#   431: '1981',
#   432: '1984',
#   433: '1985',
#   434: '1986',
#   435: '1987',
#   436: '1989',
#   437: "1990's",
#   438: '1990s',
#   439: '1991',
#   440: '1992',
#   441: '1997',
#   442: '1999',
#   443: '1999 Seattle Protest',
#   444: '19th Century',
#   445: '19th Century Russia',
#   446: '19th century',
#   447: '1D characterisation',
#   448: '1D characters',
#   449: '1st century',
#   450: '2',
#   451: '2 movies in 1',
#   452: '2 or 3 hilarious parts - but too boring to see again',
#   453: '2-2-2008',
#   454: '2-2-208',
#   455: '2-dimensional',
#   456: '2.5',
#   457: "20's",
#   458: '20.01.06',
#   459: '20.03.06',
#   460: '20.08.05',
#   461: '2000',
#   462: '2000 style',
#   463: '2000s',
#   464: '2000s Horror',
#   465: '2001',
#   466: '2001 inverted',
#   467: '2001 knockoff',
#   468: '2001-like',
#   469: '2003',
#   470: '2004',
#   471: '2006',
#   472: '2006 Best Picture Oscar Nominee',
#   473: '2006 reissue in Stereoscopic 3-D',
#   474: '20060407',
#   475: '2008 crisis',
#   476: '2009 reissue in Stereoscopic 3-D',
#   477: '2010',
#   478: '2010s',
#   479: '2012',
#   480: '2013',
#   481: '2014',
#   482: '2015',
#   483: '2015 Academy Award Nomination ANIMATED FEATURE FILM',
#   484: '2015 Academy Award Nomination BEST ACTOR',
#   485: '2015 Academy Award Nomination BEST ACTOR SUPPORTING ROLE',
#   486: '2015 Academy Award Nomination BEST ACTRESS',
#   487: '2015 Academy Award Nomination BEST ACTRESS SUPPORTING ROLE',
#   488: '2015 Academy Award Nomination BEST PICTURE',
#   489: '2015-08',
#   490: '2016',
#   491: '2016 DVD-R',
#   492: '2017',
#   493: '2018',
#   494: '2018.fresh.air',
#   495: '2019',
#   496: '2020 relook',
#   497: '2020-2 relook',
#   498: '2020-relook',
#   499: '2020s',
#   500: '2029',
#   501: '2030s',
#   502: '2035',
#   503: '2036',
#   504: '2040s',
#   505: '2080s',
#   506: '20s',
#   507: '20th Century',
#   508: '20th Century Fox fanfare',
#   509: '20th century',
#   510: '20th century current events',
#   511: '20th century history',
#   512: '20th century period piece',
#   513: '21.02.06',
#   514: '21.03.06',
#   515: '21.08.05',
#   516: '2140s',
#   517: '21st Century',
#   518: '21st century',
#   519: '22-7-2007',
#   520: '22.01.06',
#   521: '220 foot free-fall',
#   522: '23',
#   523: '23-12-2007',
#   524: '23-5-2007',
#   525: '23.03.06',
#   526: '2323232',
#   527: '25',
#   528: '25-02-2007',
#   529: '25.02.06',
#   530: '25th century',
#   531: '26.01.06',
#   532: '26.02.06',
#   533: '26.03.06',
#   534: '27-01-2007',
#   535: '27-12-2007',
#   536: '28 days later rip-off',
#   537: '28.06.06',
#   538: '28.12.05',
#   539: '29--9-2007',
#   540: '29-11-2006',
#   541: '29.03.06',
#   542: '2CV',
#   543: '2D',
#   544: '2D Animation',
#   545: '2D Disney Animation',
#   546: '2D animation',
#   547: '2D characters',
#   548: '2D/3D hybrid Animation',
#   549: '2d animation',
#   550: '2nd century',
#   551: '2nd world war',
#   552: '2nd worst Gilliam',
#   553: '2nd worst movie ever made. Tom Kinny\'s "Binky" is the creepiest clown ever.',
#   554: '2Âº best batmam movie',
#   555: '3',
#   556: '3 dimensional',
#   557: '3 stars for special effects',
#   558: '3 tissues',
#   559: '3-12-2006',
#   560: '3-D',
#   561: '3-D animation',
#   562: '3-Depix',
#   563: '3-hours of sex and drugs',
#   564: '3.5',
#   565: '3/11',
#   566: '30 Daze Of Shite',
#   567: '30 for 30',
#   568: '30 rock',
#   569: '30% truth 70% story',
#   570: '30.03.06',
#   571: '300',
#   572: '300 Spoof',
#   573: '30s',
#   574: '31-3-2007',
#   575: '31.03.06',
#   576: '35mm',
#   577: '360 degree panning',
#   578: '360 video',
#   579: '39 shots',
#   580: '3D',
#   581: '3D character',
#   582: '3D effects',
#   583: '3D in your face',
#   584: '3D version',
#   585: '3d',
#   586: '3d animation',
#   587: '3d graphics',
#   588: '3d printing',
#   589: '3d version',
#   590: '4',
#   591: '4 alternate versions',
#   592: '4 or 4.5?',
#   593: '4.5',
#   594: '4.5-filmafinity',
#   595: '40 year old virgin',
#   596: "40's",
#   597: '40s',
#   598: '44 Magnum',
#   599: '47 Ronin',
#   600: '47 ronin',
#   601: '48 fps',
#   602: '48 frames per second',
#   603: '4:3',
#   604: '4:3 aspect ratio',
#   605: '4:3 format',
#   606: '4D dissociation',
#   607: '4K',
#   608: '4d',
#   609: '4th of July',
#   610: '4th wall',
#   611: '5 Han Solos',
#   612: '5 stars',
#   613: '5+ out of 5',
#   614: '5+++',
#   615: '5,2-filmafinity',
#   616: '5,4-filmaffinity',
#   617: '5,6-filmafinity',
#   618: '5-7-2008',
#   619: '5-8-2007',
#   620: '5-FilmAffinity',
#   621: '5.1-FilmAffinity',
#   622: '5.3-FilmAffinity',
#   623: '5.5-FilmAffinity',
#   624: '5.7-FilmAffinity',
#   625: '5.8-FilmAffinity',
#   626: '5.9-FilmAffinity',
#   627: '50',
#   628: '50 Cent',
#   629: '50 cent',
#   630: '50 shades of gray',
#   631: "50's",
#   632: "50's & 60's",
#   633: "50's & 60's music",
#   634: '50000 on Double Dragon',
#   635: '50s',
#   636: '50s sci-fi',
#   637: '50s-60s popcorn movie',
#   638: '55 FilmAffinity',
#   639: '55 movies every kid should see--Entertainment Weekly',
#   640: '5\\+++',
#   641: '5th century',
#   642: '6 souls',
#   643: '6,2-filmaffinity',
#   644: '6,5-filmaffinity',
#   645: '6-10-2007',
#   646: '6-4-2007',
#   647: '6.1-FilmAffinity',
#   648: '6.2-FilmAffinity',
#   649: '6.3-FilmAffinity',
#   650: '6.4-FilmAffinity',
#   651: '6.5-FilmAffinity',
#   652: '6.7-FilmAffinity',
#   653: '6.8-FilmAffinity',
#   654: "60's",
#   655: '60s',
#   656: '60s horror',
#   657: '60s music',
#   658: '60s sci-fi',
#   659: '60s setting',
#   660: '6565858tfkjfk',
#   661: '65mm',
#   662: '666',
#   663: '6ir6',
#   664: '7',
#   665: '7 Up',
#   666: '7 days',
#   667: '7 deadly sins',
#   668: '7-10-2007',
#   669: '7-2007',
#   670: '7-4-2007',
#   671: '7-year old girl',
#   672: '7.0-FilmAffinity',
#   673: '7.1-FilmAffinity',
#   674: '7.2-FilmAffinity',
#   675: '7.3-FilmAffinity',
#   676: '7.4-FilmAffinity',
#   677: '7.5-FilmAffinity',
#   678: '7.6-FilmAffinity',
#   679: '7.7-FilmAffinity',
#   680: '7.8-FilmAffinity',
#   681: "70's",
#   682: "70's new york",
#   683: "70's style ending",
#   684: '70mm',
#   685: '70mm blowup',
#   686: '70s',
#   687: '70s aesthetic',
#   688: '70s horror',
#   689: '70s horror movie references',
#   690: '70s plot',
#   691: '70s sci-fi',
#   692: '7n Up (series)',
#   693: '8 Track Tape Collectors',
#   694: '8 bit',
#   695: '8 films to die for',
#   696: '8.2-FilmAffinity',
#   697: '8.3-FilmAffinity',
#   698: '8.4-FilmAffinity',
#   699: '8.7-FilmAffinity',
#   700: '80',
#   701: "80'",
#   702: "80's",
#   703: "80's Music",
#   704: "80's Soundtrack",
#   705: "80's band",
#   706: "80's cartoons",
#   707: "80's cheese",
#   708: "80's classic",
#   709: "80's cult movie",
#   710: "80's fashion",
#   711: "80's goth cult movie",
#   712: "80's high fantasy",
#   713: "80's horror",
#   714: "80's humor",
#   715: "80's music",
#   716: "80's nostalgia",
#   717: "80's slang",
#   718: "80's soundtrack",
#   719: "80's style",
#   720: '80s',
#   721: '80s Horror',
#   722: '80s Slasher',
#   723: '80s Soundtrack',
#   724: '80s comedy',
#   725: '80s horror',
#   726: '80s music',
#   727: '80s nostalgia',
#   728: '80s references',
#   729: '80s sci-fi',
#   730: '80s soundtrack',
#   731: '80s style',
#   732: '80s synth music',
#   733: '80s video',
#   734: '80s video games',
#   735: '85',
#   736: '89',
#   737: "8o's",
#   738: '9-11',
#   739: '9-2-2007',
#   740: '9-2007',
#   741: '9/1',
#   742: '9/11',
#   743: '9/11 reference',
#   744: '90 minute story stretched to ~180',
#   745: '90% computer graphics',
#   746: '90% drama 10% comedy',
#   747: "90's",
#   748: "90's internet",
#   749: "90's music",
#   750: '90210 on acid',
#   751: '90s',
#   752: '90s atmosphere',
#   753: '90s classic',
#   754: '90s club culture',
#   755: '90s cynicisim',
#   756: '90s dystopia',
#   757: '90s horror',
#   758: '90s kid',
#   759: '90s sci-fi',
#   760: '911',
#   761: '94 long minutes',
#   762: '95% of the spectators left early',
#   763: '9ine Queens Was A Better Title...& Film',
#   764: '9th century',
#   765: ':)',
#   766: ':-)',
#   767: '; bigoted',
#   768: '<3',
#   769: '===========',
#   770: '============',
#   771: '=============',
#   772: '==============',
#   773: '===============',
#   774: '================',
#   775: '=================',
#   776: '==================',
#   777: '===================',
#   778: '====================',
#   779: '=====================',
#   780: '=======================',
#   781: '========================',
#   782: '=========================',
#   783: '===========================',
#   784: '==============================',
#   785: '>suspense',
#   786: '?',
#   787: '????????????????????',
#   788: '?adapted from:book',
#   789: '?adapted from:comic',
#   790: '?alter ego',
#   791: '?alternate endings',
#   792: '?android(s)/cyborg(s)',
#   793: '?android/cyborgs',
#   794: '?author:Homer',
#   795: '?author:Len Wein',
#   796: '?author:Rudyard Kipling',
#   797: '?author:Stephen King',
#   798: '?author:Tennessee Williams',
#   799: '?biographical',
#   800: '?social commentary',
#   801: '@2010',
#   802: '@childhood',
#   803: 'A Bad Copy Of Departed Which Was A Re-Hash Of Infernal Affairs',
#   804: 'A Better Tomorrow Trilogy',
#   805: 'A Brilliant Young Mind',
#   806: 'A Comedy Version Of Matchpoint',
#   807: 'A Deadhead With A Parrot Fetish',
#   808: 'A Detective Story',
#   809: 'A Drunk',
#   810: 'A Girl for Joe -- reissue title',
#   811: 'A Good Tom Cruise Movie',
#   812: 'A LO JAMES BOND',
#   813: 'A Legend',
#   814: 'A Lista de Schindler',
#   815: 'A MUST SEE',
#   816: 'A Married Couples Excuse To Shag On Film',
#   817: 'A Spike Lee Joint',
#   818: 'A Streetcar Named Desire',
#   819: 'A Very Special Episode of Blossom',
#   820: 'A bit stupid',
#   821: 'A classic scifi movie',
#   822: 'A complete waste of time!',
#   823: 'A dangerous message',
#   824: 'A feel good movie. A bit religious too I would think',
#   825: 'A fun introduction to the epic film series which will keep you on the edge of your seat during the good vs evil battles.  Fantastic special effects, incredible characters and futuristic landscapes.',
#   826: 'A good one time watch',
#   827: 'A great intro to new exciting characters.',
#   828: 'A hole',
#   829: 'A little stupid but funny',
#   830: 'A love love story',
#   831: 'A new Classic',
#   832: 'A nicy romantic comedy',
#   833: 'A non-typical story leads to a fine ending',
#   834: 'A picturesque English horror story. In good taste.',
#   835: 'A presidential look-alike takes over as Commander in Chief and uses his time in office to work for ordinary people.',
#   836: 'A solid three-star film. Well done everyone!',
#   837: 'A tribute movie butchered by the short sidedness',
#   838: 'A very touching',
#   839: 'A very touching movie',
#   840: 'A very touching movie. Great role played by Mel Gibson as William Wallace',
#   841: 'A visual poem',
#   842: 'A western set in an alien world',
#   843: 'A whimsical',
#   844: 'A wonderful satire address the importance American society has placed on cultural savvy and political connectedness over intellect/critical thinking.',
#   845: 'A Última Tentação de Cristo',
#   846: 'A. Edward Sutherland',
#   847: 'A. S. Byatt',
#   848: 'A.I.',
#   849: 'A.I., sci-fi',
#   850: 'A.J. Cook',
#   851: 'A.R. Murugadoss',
#   852: 'A1 formulaic crap',
#   853: 'A24',
#   854: 'AA',
#   855: 'ABA',
#   856: 'ABBA',
#   857: 'ABSURDA',
#   858: 'ACTION',
#   859: "ACTOR'S LIFE",
#   860: 'ADD',
#   861: 'ADHD',
#   862: 'ADOLESCENCE IS HELL',
#   863: 'ADVENTURE',
#   864: 'AEK',
#   865: 'AFI # 41',
#   866: 'AFI #1',
#   867: 'AFI #10',
#   868: 'AFI #100',
#   869: 'AFI #11',
#   870: 'AFI #12',
#   871: 'AFI #13',
#   872: 'AFI #14',
#   873: 'AFI #15',
#   874: 'AFI #16',
#   875: 'AFI #17',
#   876: 'AFI #18',
#   877: 'AFI #19',
#   878: 'AFI #2',
#   879: 'AFI #20',
#   880: 'AFI #21',
#   881: 'AFI #22',
#   882: 'AFI #23',
#   883: 'AFI #24',
#   884: 'AFI #25',
#   885: 'AFI #26',
#   886: 'AFI #27',
#   887: 'AFI #28',
#   888: 'AFI #3',
#   889: 'AFI #30',
#   890: 'AFI #31',
#   891: 'AFI #32',
#   892: 'AFI #33',
#   893: 'AFI #34',
#   894: 'AFI #35',
#   895: 'AFI #36',
#   896: 'AFI #37',
#   897: 'AFI #38',
#   898: 'AFI #39',
#   899: 'AFI #4',
#   900: 'AFI #40',
#   901: 'AFI #42',
#   902: 'AFI #43',
#   903: 'AFI #44',
#   904: 'AFI #45',
#   905: 'AFI #46',
#   906: 'AFI #47',
#   907: 'AFI #48',
#   908: 'AFI #49',
#   909: 'AFI #5',
#   910: 'AFI #50',
#   911: 'AFI #51',
#   912: 'AFI #52',
#   913: 'AFI #53',
#   914: 'AFI #54',
#   915: 'AFI #55',
#   916: 'AFI #56',
#   917: 'AFI #57',
#   918: 'AFI #58',
#   919: 'AFI #59',
#   920: 'AFI #6',
#   921: 'AFI #60',
#   922: 'AFI #61',
#   923: 'AFI #62',
#   924: 'AFI #63',
#   925: 'AFI #64',
#   926: 'AFI #65',
#   927: 'AFI #66',
#   928: 'AFI #67',
#   929: 'AFI #68',
#   930: 'AFI #69',
#   931: 'AFI #7',
#   932: 'AFI #70',
#   933: 'AFI #71',
#   934: 'AFI #72',
#   935: 'AFI #73',
#   936: 'AFI #74',
#   937: 'AFI #75',
#   938: 'AFI #76',
#   939: 'AFI #77',
#   940: 'AFI #78',
#   941: 'AFI #79',
#   942: 'AFI #8',
#   943: 'AFI #80',
#   944: 'AFI #81',
#   945: 'AFI #82',
#   946: 'AFI #83',
#   947: 'AFI #84',
#   948: 'AFI #85',
#   949: 'AFI #86',
#   950: 'AFI #87',
#   951: 'AFI #88',
#   952: 'AFI #89',
#   953: 'AFI #9',
#   954: 'AFI #91',
#   955: 'AFI #92',
#   956: 'AFI #93',
#   957: 'AFI #94',
#   958: 'AFI #95',
#   959: 'AFI #96',
#   960: 'AFI #97',
#   961: 'AFI #98',
#   962: 'AFI #99',
#   963: 'AFI 10 (courtroom drama)',
#   964: 'AFI 100',
#   965: 'AFI 100 (Cheers)',
#   966: 'AFI 100 (Laughs)',
#   967: 'AFI 100 (Movie Quotes)',
#   968: 'AFI 100 (Thrills)',
#   969: 'AFI Movie of the Year',
#   970: 'AFI top 100 (#97)',
#   971: 'AFI top 100 laughs (#14)',
#   972: 'AFI top 100 passions (#51)',
#   973: 'AFTER THE APOCALYPSE',
#   974: 'AFrica',
#   975: 'AGE DISPARITY ROMANCE',
#   976: 'AGI',
#   977: 'AI',
#   978: 'AIDS',
#   979: 'AIDs',
#   980: 'AIRE DE VIDEOCLIP',
#   981: 'AJ Langer',
#   982: 'AJ Michalka',
#   983: 'AJ Schnack',
#   984: 'ALCOHOLISM',
#   985: 'ALF',
#   986: 'ALL THE ACTORS WERE JUST WONDERFUL!! A movie for anybody',
#   987: 'ALL WASHED UP',
#   988: 'ALS',
#   989: 'ALT romantic comedy',
#   990: 'AMATEUR SLEUTHS',
#   991: 'AMC',
#   992: 'AMC 24',
#   993: 'AMDG',
#   994: 'AMERICAN ABROAD',
#   995: 'AMERICANADA',
#   996: 'AMERICANS',
#   997: 'AMERICANS ABROAD',
#   998: 'AMNESIA',
#   999: 'ANAL BUTTER',
#   ...}}
